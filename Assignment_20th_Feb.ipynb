# %% [markdown]
# # Assignment Answers

# %% [markdown]
# # 1.

# %% [markdown]
# 1. GET:
# - It is a HTTP method whic is used to request the data from specified source passed in a URL.
# - It not secure as data in passed in the URL itself which can be viewwd by everyone.
# - It has limitation with size of data we can send, which is 2048 characters at maximum.
# 2. POST:
# - It is also a HTTP method which is used to send data to a server.
# - It is secure way of transferring data as it is passed in the request body of HTTP request.
# - We can send data of any length using this method.

# %% [markdown]
# # 2.

# %% [markdown]
# - It is an object that Flask uses to create in order to handle all the data sent from a client machine to sent machine.
# - The data sent can then be reteived through __request__ object and further operations can be performed on it.
# - It can get data either directly from the URL using the GET method, or from other applications wusing POST method.

# %% [markdown]
# # 3.

# %% [markdown]
# - It is a class defined in python Flask, which is used to redirect user to other location.
# - It creates a response object with some status code as specified tobe sent to the client.
# - It contains the following parameters:
# <br><br>
# <b>location parameter:</b> It is the URL where response should be redirected.
# <br>
# <b>statuscode:</b> It is sent to browser’s header, defaults to 302.
# <br>
# <b>response:</b> It is used to instantiate response.

# %% [markdown]
# # 4.

# %% [markdown]
# ##### Part-1:<br><br>
# - Templates are files or folders that contains document to be rendered.
# - It is rendered with the required static data or dynamic data passed into the placeholders.
# - We basically use it to create HTML document containing information to be shown to the client.
# <br><br>
# ##### Part-2:<br><br>
# - render_template() function is used to render the document specified as template.
# - It provide us with the functionality to utilize the intended functions of the templates.

# %% [markdown]
# # 5.

# %% [markdown]
# - Code:<br>

# %%
# Importing Libraries
from flask import Flask
from flask import request
from flask import jsonify

# Creating Flask Object
app = Flask(__name__)

#  Creating route

@app.route("/using_postman", methods=["POST"])
def display_name():

    case = request.json["Case"]
    fname = request.json["First Name"] 
    lname = request.json["Last Name"]
    res= ""

    if(case.lower() == "show first name"):
        res = "First name of the person is {}.".format(fname)
    if(case.lower() == "show last name"):
        res = "Last name of the person is {}.".format(lname)
    if(case.lower() == "show full name"):
        res = "Full name of the person is {} {}.".format(fname,lname)
    
    return res

# %% [markdown]
# - Image:<br>

# %% [markdown]
# ![Feb_20-1.jpg](attachment:3ce391ff-9608-4ad6-9c4d-1c633eb39d8f.jpg)

# %% [markdown]
# ![Feb_20-2.jpg](attachment:971dc5bb-a563-48b5-953a-905bc2cc9f6a.jpg)

# %% [markdown]
# ![Feb_20-3.jpg](attachment:b1153b52-8404-41cf-9e87-1bf4825af6bd.jpg)
